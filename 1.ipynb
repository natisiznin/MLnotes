# %%
corpus="""
hello this is sarthak! and i hate mosquitoes.
and someone who looks into others screen a lot.
"""

\

# %%
import nltk

# Download the required punkt tokenizer data
nltk.download('punkt')

# Note: If you are using NLTK version 3.8.2 or newer, 
# you should also download 'punkt_tab'
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sarth\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\sarth\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize

# %%
sent_tokenize(corpus)
# Out:
# ['\nhello this is sarthak!',
#  'and i hate mosquitoes.',
#  'and someone who looks into others screen a lot.']

# %%
## paragraph to words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['hello',
#  'this',
#  'is',
#  'sarthak',
#  '!',
#  'and',
#  'i',
#  'hate',
#  'mosquitoes',
#  '.',
#  'and',
#  'someone',
#  'who',
#  'looks',
#  'into',
#  'others',
#  'screen',
#  'a',
#  'lot',
#  '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['hello',
#  'this',
#  'is',
#  'sarthak',
#  '!',
#  'and',
#  'i',
#  'hate',
#  'mosquitoes',
#  '.',
#  'and',
#  'someone',
#  'who',
#  'looks',
#  'into',
#  'others',
#  'screen',
#  'a',
#  'lot',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['hello',
#  'this',
#  'is',
#  'sarthak',
#  '!',
#  'and',
#  'i',
#  'hate',
#  'mosquitoes.',
#  'and',
#  'someone',
#  'who',
#  'looks',
#  'into',
#  'others',
#  'screen',
#  'a',
#  'lot',
#  '.']

# %% [markdown]
# ## stemmer ##

# %%
from nltk.stem import PorterStemmer

# %%
stemming=PorterStemmer()

# %%
for word in words:
    print(word+"---->"+stemming.stem())

# %%
from nltk.stem import RegexpStemmer

# %%
reg_stemmer=RegexpStemmer('ing$|s$|e$|able$', min=4)
## where ever there are ing, e ,s , able in the end of the word just remove them 
## if we put dollar in the start then it will remove these from the start and if we remove dollar then it will remove them generally

# %%
reg_stemmer.stem('eating')
# Out:
# 'eat'

# %% [markdown]
# ### snowball stemmer

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sarth\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sarth\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\sarth\AppData\Roaming\nltk_data...
# True

# %%
from nltk import SnowballStemmer

# %%
snowball_stemmer=SnowballStemmer('english',ignore_stopwords='True')

# %%
stemming.stem('sportingly'),stemming.stem('fairly')
# Out:
# ('sportingli', 'fairli')

# %%
snowball_stemmer.stem('sportingly'),snowball_stemmer.stem('fairly')
# Out:
# ('sport', 'fair')

# %% [markdown]
# ## lemitization

# %%
from nltk.stem import WordNetLemmatizer
lemmitizer=WordNetLemmatizer()

# %%
lemmitizer.lemmatize("eating",pos='v')
# Out:
# 'eat'

# %%
lemmitizer.lemmatize("best",pos='v')
# Out:
# 'best'
